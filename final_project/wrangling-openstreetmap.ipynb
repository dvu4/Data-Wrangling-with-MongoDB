# %% [markdown]
# # Wrangling  OpenStreetMap Data  with MongoDB
# ### Duc Vu

# %% [markdown]
# OpenStreetMap is an open project that lets eveyone use and create a free editable map of the world.

# %% [markdown]
# ## 1. Chosen Map Area

# %% [markdown]
# In this project, I choose to analyze data from Boston, Massachusetts want to show you to fix one type of error, that is the address of the street. And not only that, I also will show you how to put the data that has been audited into MongoDB instance. We also use MongoDB's Agregation Framework to get overview and analysis of the data

# %%
from IPython.display import HTML
HTML('<iframe width="425" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" \
src="http://www.openstreetmap.org/export/embed.html?bbox=-81.793212890625%2C28.75441649498853%2C-80.85113525390625%2C29.756032197482973\
&amp;layer=mapnik"></iframe><br/><small><a href="http://www.openstreetmap.org/#map=10/29.2565/-81.3222" \
target="_blank">View Larger Map</a></small>')
# Out:
# <iframe width="425" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="http://www.openstreetmap.org/export/embed.html?bbox=-81.793212890625%2C28.75441649498853%2C-80.85113525390625%2C29.756032197482973&amp;layer=mapnik"></iframe><br/><small><a href="http://www.openstreetmap.org/#map=10/29.2565/-81.3222" target="_blank">View Larger Map</a></small>

# %%
from IPython.display import HTML
HTML('<iframe width="425" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" \
src="http://www.openstreetmap.org/export/embed.html?bbox=-71.442,42.1858,-70.6984,42.4918&amp;layer=mapnik"></iframe><br/>')
# Out:
# <iframe width="425" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="http://www.openstreetmap.org/export/embed.html?bbox=-71.442,42.1858,-70.6984,42.4918&amp;layer=mapnik"></iframe><br/>

# %%
from IPython.display import HTML
HTML('<iframe width="425" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" \
src="http://www.openstreetmap.org/export/embed.html?bbox=-88.0671,41.7314,-87.3235,42.0396&amp;layer=mapnik"></iframe><br/>')
# Out:
# <iframe width="425" height="350" frameborder="0" scrolling="no" marginheight="0" marginwidth="0" src="http://www.openstreetmap.org/export/embed.html?bbox=-88.0671,41.7314,-87.3235,42.0396&amp;layer=mapnik"></iframe><br/>

# %% [markdown]
# The dataset is here https://s3.amazonaws.com/metro-extracts.mapzen.com/boston_massachusetts.osm.bz2

# %%
import requests

url = 'http://overpass-api.de/api/map?bbox=-81.5600,28.8400,-80.7400,29.6713'
#filename = 'volusia_flagler.osm'
#filename = 'chicago_illinois.osm'
filename = 'boston_massachusetts.osm'

# %%
def download_file(url, local_filename):
    # stream = True allows downloading of large files; prevents loading entire file into memory
    r = requests.get(url, stream = True)
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=1024): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
                f.flush()
                
download_file(url, filename)

# %% [markdown]
# ## 2. Auditing the Data

# %%
import xml.etree.cElementTree as ET
import pprint

def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags:
                tags[elem.tag] +=1
            else:
                tags[elem.tag]= 1
                
        return tags
#tags = count_tags('chicago_illinois.osm')
tags = count_tags(filename)
pprint.pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 27231,
#  'meta': 1,
#  'nd': 378367,
#  'node': 322114,
#  'note': 1,
#  'osm': 1,
#  'relation': 344,
#  'tag': 217210,
#  'way': 29774}

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":

        if lower.search(element.attrib['k']):
            keys["lower"] += 1
        elif lower_colon.search(element.attrib['k']):
            keys["lower_colon"] += 1
        elif problemchars.search(element.attrib['k']):
            keys["problemchars"] +=1
        else:
            keys["other"] +=1
        

    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys


keys = process_map(filename)
pprint.pprint(keys)
# Out:
# {'lower': 83013, 'lower_colon': 127022, 'other': 7174, 'problemchars': 1}

# %%
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        #print element.attrib
        
        try:
            users.add(element.attrib['uid'])
        except KeyError:
            continue
        '''
        if "uid" in element.attrib:
            users.add(element.attrib['uid'])
        '''
    return users

users = process_map(filename)
#pprint.pprint(users)
print len(users)
# Out:
# 305

# %% [markdown]
# ## 3. Problems Encountered in the Map

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# %%
def audit_street_type(street_types, street_name, rex):
    #m = street_type_re.search(street_name)
    m = rex.search(street_name)
    #print m
    #print m.group()
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %%
def audit(osmfile,rex):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'],rex)

    return street_types

# %%
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

# %%
st_types = audit(filename, rex = street_type_re)
pprint.pprint(dict(st_types))
# Out:
# {'1': set(['US 1']),
#  '10': set(['Deltona Boulevard, #10']),
#  '100': set(['W. Highway 100']),
#  '13': set(['Saxon Boulevard Suite 13']),
#  '201': set(['Saxon Boulevard, Suite 201']),
#  '44': set(['State Road 44']),
#  'A': set(['Saxon Boulevard, Suite A']),
#  'Ave': set(['Central Ave',
#              'E Arizona Ave',
#              'E Euclid Ave',
#              'E MIchigan Ave',
#              'E Michigan Ave',
#              'E Minnesota Ave',
#              'E Pennsylania Ave',
#              'E Pennsylvania Ave',
#              'E Stetson Ave',
#              'E University Ave',
#              'N Amelia Ave',
#              'Rhode Island Ave',
#              'W Minnesota Ave',
#              'W Pennsylvania Ave']),
#  'Blvd': set(['Commerce Blvd',
#               'Harley Strickland Blvd',
#               'Howland Blvd',
#               'Mahogany Blvd',
#               'N Woodland Blvd',
#               'S Clyde Morris Blvd',
#               'S Woodland Blvd',
#               'Seasame Blvd',
#               'Town Center Blvd',
#               'W International Speedway Blvd',
#               'West Granada Blvd']),
#  'Blvd.': set(['Ocean Shore Blvd.',
#                'Oceanshore Blvd.',
#                'West International Speedway Blvd.']),
#  'Cir': set(['Fraternity Cir']),
#  'Circle': set(['Amber Circle']),
#  'Dr': set(['Cypress Edge Dr',
#             'E Bert Fish Dr',
#             'Flagler Plaza Dr',
#             'N Bert FIsh Dr',
#             'N Bert Fish Dr',
#             'Rymfire Dr']),
#  'East': set(['Palm Coast Pkwy East']),
#  'Ln': set(['Bainbridge Ln']),
#  'N': set(['Garden St N', 'Old Kings Rd N']),
#  'Pkwy': set(['City Center Pkwy', 'Palm Coast Pkwy']),
#  'Pky': set(['Pine Lakes Pky']),
#  'Rd': set(['W Highbanks Rd']),
#  'Rd.': set(['North Nova Rd.']),
#  'Run': set(['Wolf Pack Run']),
#  'South': set(['Ibis Court South']),
#  'St': set(['10th St']),
#  'St.': set(['Third St.']),
#  'Way': set(['Kings Way']),
#  'West': set(['Palm Coast Pkwy West'])}

# %%
# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Rd." : "Road",
            "Ave" : "Avenue",
            "ave" : "Avenue",
            "Street." : "Street",
            "St,": "Street", 
            "ST": "Street", 
            "Sq." : "Square",
            "Rd" : "Road",
            "Pl": "Place",
            "HIghway": "Highway",
            "LEVEL": "Level",
            "Ct" : "Court",
            "Ave.": "Avenue"
            }

# %%
def update_name(name, mapping,rex):

    #m = street_type_re.search(name)
    m = rex.search(name)
    if m:
        street_type = m.group()
        new_street_type = mapping[street_type]
        name = re.sub(rex, new_street_type, name) # re.sub(old_pattern, new_pattern, file)
        #name = street_type_re.sub(new_street_type, name)
    return name

# %%
for st_type, ways in st_types.iteritems():
    if st_type in mapping:
        for name in ways:
            better_name = update_name(name, mapping, rex = street_type_re)
            print name, "=>", better_name
# Out:
# Third St. => Third Street
# W Highbanks Rd => W Highbanks Road
# North Nova Rd. => North Nova Road
# 10th St => 10th Street
# E Minnesota Ave => E Minnesota Avenue
# E Euclid Ave => E Euclid Avenue
# E Arizona Ave => E Arizona Avenue
# Central Ave => Central Avenue
# E MIchigan Ave => E MIchigan Avenue
# E Stetson Ave => E Stetson Avenue
# W Pennsylvania Ave => W Pennsylvania Avenue
# E Michigan Ave => E Michigan Avenue
# W Minnesota Ave => W Minnesota Avenue
# N Amelia Ave => N Amelia Avenue
# E University Ave => E University Avenue
# E Pennsylvania Ave => E Pennsylvania Avenue
# Rhode Island Ave => Rhode Island Avenue
# E Pennsylania Ave => E Pennsylania Avenue

# %%
cardinal_dir_re = re.compile(r'^[NSEW]\b\.?', re.IGNORECASE)

# %%
dir_st_types = audit(filename, rex = cardinal_dir_re)
pprint.pprint(dict(dir_st_types))
# Out:
# {'E': set(['E Arizona Ave',
#            'E Bert Fish Dr',
#            'E Euclid Ave',
#            'E MIchigan Ave',
#            'E Michigan Ave',
#            'E Minnesota Ave',
#            'E Pennsylania Ave',
#            'E Pennsylvania Ave',
#            'E Stetson Ave',
#            'E University Ave']),
#  'N': set(['N Amelia Ave',
#            'N Bert FIsh Dr',
#            'N Bert Fish Dr',
#            'N Woodland Blvd']),
#  'S': set(['S Clyde Morris Blvd', 'S Woodland Blvd']),
#  'W': set(['W Granada Boulevard',
#            'W Highbanks Rd',
#            'W International Speedway Blvd',
#            'W Minnesota Ave',
#            'W Pennsylvania Ave']),
#  'W.': set(['W. Highway 100'])}

# %%
cardinal_directions_mapping = \
    {
        "E" : "East",
        "N" : "North",
        "S" : "South",
        "W" : "West"
    }

# %%
for st_type, ways in dir_st_types.iteritems():
    if st_type in cardinal_directions_mapping:
        for name in ways:
            better_name = update_name(name, cardinal_directions_mapping, rex = cardinal_dir_re)
            print name, "=>", better_name
# Out:
# S Woodland Blvd => South Woodland Blvd
# S Clyde Morris Blvd => South Clyde Morris Blvd
# E Minnesota Ave => East Minnesota Ave
# E Pennsylania Ave => East Pennsylania Ave
# E Arizona Ave => East Arizona Ave
# E MIchigan Ave => East MIchigan Ave
# E Stetson Ave => East Stetson Ave
# E Michigan Ave => East Michigan Ave
# E University Ave => East University Ave
# E Pennsylvania Ave => East Pennsylvania Ave
# E Bert Fish Dr => East Bert Fish Dr
# E Euclid Ave => East Euclid Ave
# W International Speedway Blvd => West International Speedway Blvd
# W Pennsylvania Ave => West Pennsylvania Ave
# W Highbanks Rd => West Highbanks Rd
# W Granada Boulevard => West Granada Boulevard
# W Minnesota Ave => West Minnesota Ave
# N Woodland Blvd => North Woodland Blvd
# N Amelia Ave => North Amelia Ave
# N Bert Fish Dr => North Bert Fish Dr
# N Bert FIsh Dr => North Bert FIsh Dr

# %%
osm_file = open(filename, "r")
address_count = 0

for event, elem in ET.iterparse(osm_file, events=("start",)):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"): 
            if is_street_name(tag):
                address_count += 1

address_count
# Out:
# 222

# %% [markdown]
# ## 4. Preparing for MongoDB

# %%
CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :

        node["type"] = element.tag
        
        #for key in element.attrib.keys()
        for key in element.attrib:
            #print key
            
            if key in CREATED:
                if "created" not in node:
                    node["created"] = {}
                node["created"][key] = element.attrib[key]
            
            elif key in ["lat","lon"]:
                if "pos" not in node:
                    node["pos"] = [None, None]
                if key == "lat":
                    node["pos"][0] = float(element.attrib[key])
                elif key == "lon":
                    node["pos"][1] = float(element.attrib[key])  
            else:
                node[key] = element.attrib[key]
           
            for tag in element.iter("tag"):
                tag_key = tag.attrib["k"]   # key
                tag_value = tag.attrib["v"] # value
                if not problemchars.match(tag_key):
                    if tag_key.startswith("addr:"):# Single colon beginning with addr
                        if "address" not in node:
                            node["address"] = {}
                        sub_addr = tag_key[len("addr:"):]
                        if not lower_colon.match(sub_addr): # Tags with no colon
                            node["address"][sub_addr] = tag_value
                    elif lower_colon.match(tag_key): # Single colon not beginnning with "addr:" 
                        node[tag_key] = tag_value 
                    else:
                        node[tag_key] = tag_value # Tags with no colon, not beginnning with "addr:" 
     
        for nd in element.iter("nd"):
            if "node_refs" not in node:
                node["node_refs"] = []
            node["node_refs"].append(nd.attrib["ref"]) 

        #print node
        return node
    else:
        return None

# %%
import codecs
import json

def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

process_map(filename)
# Out:
# [{'created': {'changeset': '10423645',
#    'timestamp': '2012-01-18T00:10:09Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '3'},
#   'id': '26932333',
#   'pos': [28.8386787, -81.3243472],
#   'type': 'node'},
#  {'created': {'changeset': '4233448',
#    'timestamp': '2010-03-25T21:35:10Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '2'},
#   'id': '26932350',
#   'pos': [28.8589616, -81.3236483],
#   'type': 'node'},
#  {'created': {'changeset': '4233448',
#    'timestamp': '2010-03-25T21:35:10Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '2'},
#   'id': '26932351',
#   'pos': [28.8602677, -81.3243886],
#   'type': 'node'},
#  {'created': {'changeset': '4233448',
#    'timestamp': '2010-03-25T21:35:10Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '2'},
#   'id': '26932352',
#   'pos': [28.8609912, -81.3250216],
#   'type': 'node'},
#  {'created': {'changeset': '3531266',
#    'timestamp': '2010-01-03T18:35:11Z',
#    'uid': '113450',
#    'user': 'nfgusedautoparts',
#    'version': '2'},
#   'id': '26932572',
#   'pos': [29.0145562, -81.3516092],
#   'type': 'node'},
#  {'created': {'changeset': '14097990',
#    'timestamp': '2012-11-30T12:17:52Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '4'},
#   'id': '26932810',
#   'pos': [29.1382262, -81.3605063],
#   'railway': 'level_crossing',
#   'type': 'node'},
#  {'created': {'changeset': '14113626',
#    'timestamp': '2012-12-01T16:24:01Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '3'},
#   'id': '26932903',
#   'pos': [29.2076335, -81.4475873],
#   'railway': 'level_crossing',
#   'type': 'node'},
#  {'created': {'changeset': '12487854',
#    'timestamp': '2012-07-25T14:37:38Z',
#    'uid': '587790',
#    'user': 'JaggedMind',
#    'version': '51'},
#   'id': '54718483',
#   'pos': [28.838173, -81.3169937],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:04:30Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91746475',
#   'pos': [28.9825167, -81.5419919],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:04:30Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91746477',
#   'pos': [28.9824191, -81.5419919],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:04:30Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91746478',
#   'pos': [28.9824191, -81.541743],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:04:30Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91746480',
#   'pos': [28.9825167, -81.541743],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:06:05Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '1'},
#   'id': '91748420',
#   'pos': [28.9825317, -81.5421722],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:06:05Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '1'},
#   'id': '91748421',
#   'pos': [28.9822614, -81.5421722],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:06:05Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '1'},
#   'id': '91748422',
#   'pos': [28.9822614, -81.541743],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:06:05Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '1'},
#   'id': '91748423',
#   'pos': [28.9823891, -81.541743],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:06:05Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '1'},
#   'id': '91748424',
#   'pos': [28.9823891, -81.5420263],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:06:05Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '1'},
#   'id': '91748425',
#   'pos': [28.9825317, -81.5420263],
#   'type': 'node'},
#  {'created': {'changeset': '27579542',
#    'timestamp': '2014-12-19T22:23:18Z',
#    'uid': '999995',
#    'user': 'pkoby',
#    'version': '9'},
#   'id': '91753552',
#   'pos': [28.9642461, -81.6458441],
#   'type': 'node'},
#  {'created': {'changeset': '27579542',
#    'timestamp': '2014-12-19T22:23:18Z',
#    'uid': '999995',
#    'user': 'pkoby',
#    'version': '8'},
#   'id': '91753553',
#   'pos': [28.9641217, -81.6455158],
#   'type': 'node'},
#  {'created': {'changeset': '10876187',
#    'timestamp': '2012-03-05T04:40:34Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '9'},
#   'id': '91753554',
#   'pos': [28.9640501, -81.6451786],
#   'type': 'node'},
#  {'created': {'changeset': '10876187',
#    'timestamp': '2012-03-05T04:40:34Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '6'},
#   'id': '91753555',
#   'pos': [28.96402, -81.6448593],
#   'type': 'node'},
#  {'created': {'changeset': '10876187',
#    'timestamp': '2012-03-05T04:40:34Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '6'},
#   'id': '91753556',
#   'pos': [28.9640104, -81.6445788],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753559',
#   'pos': [28.9639698, -81.6432378],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753560',
#   'pos': [28.9639698, -81.6422164],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753561',
#   'pos': [28.9639623, -81.6419074],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753562',
#   'pos': [28.9639548, -81.6366374],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753563',
#   'pos': [28.9639248, -81.6341569],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753565',
#   'pos': [28.9638947, -81.6338823],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753567',
#   'pos': [28.9638647, -81.633642],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753568',
#   'pos': [28.9638196, -81.6334102],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753569',
#   'pos': [28.9637671, -81.6331956],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753570',
#   'pos': [28.963692, -81.6329553],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753571',
#   'pos': [28.9636394, -81.6327751],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753572',
#   'pos': [28.9635643, -81.6324661],
#   'type': 'node'},
#  {'created': {'changeset': '9466034',
#    'timestamp': '2011-10-04T04:02:01Z',
#    'uid': '60110',
#    'user': 'dale_p',
#    'version': '6'},
#   'id': '91753573',
#   'pos': [28.9634712, -81.6321881],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753574',
#   'pos': [28.9633691, -81.6319854],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753575',
#   'pos': [28.9632789, -81.6317623],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753576',
#   'pos': [28.9631663, -81.6315219],
#   'type': 'node'},
#  {'created': {'changeset': '9466034',
#    'timestamp': '2011-10-04T04:02:01Z',
#    'uid': '60110',
#    'user': 'dale_p',
#    'version': '6'},
#   'id': '91753577',
#   'pos': [28.963064, -81.6313021],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753578',
#   'pos': [28.9628284, -81.6309812],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753580',
#   'pos': [28.9621149, -81.6299941],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753581',
#   'pos': [28.961777, -81.6296079],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753582',
#   'pos': [28.9615292, -81.6293075],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753584',
#   'pos': [28.9612964, -81.6289899],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753585',
#   'pos': [28.9611086, -81.6286981],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753586',
#   'pos': [28.9609209, -81.6283548],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753587',
#   'pos': [28.9607707, -81.628063],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753588',
#   'pos': [28.960643, -81.6277196],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753590',
#   'pos': [28.9605379, -81.6274021],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:25:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '7'},
#   'id': '91753591',
#   'pos': [28.9604778, -81.6271961],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753593',
#   'pos': [28.9604253, -81.6269214],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753594',
#   'pos': [28.9603577, -81.6265523],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753595',
#   'pos': [28.9603201, -81.6262433],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753596',
#   'pos': [28.9602976, -81.6258743],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753597',
#   'pos': [28.9602751, -81.6254795],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753598',
#   'pos': [28.9602676, -81.6251275],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753599',
#   'pos': [28.9602676, -81.6239431],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753600',
#   'pos': [28.9602525, -81.6180551],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753601',
#   'pos': [28.9602375, -81.6121328],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753604',
#   'pos': [28.9602225, -81.606159],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753605',
#   'pos': [28.9602075, -81.6024597],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753606',
#   'pos': [28.9602225, -81.6021335],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753608',
#   'pos': [28.9602525, -81.6017044],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753609',
#   'pos': [28.9603201, -81.6011465],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753610',
#   'pos': [28.9603877, -81.6007688],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753611',
#   'pos': [28.9605079, -81.6003826],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753612',
#   'pos': [28.9607031, -81.5998247],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753613',
#   'pos': [28.960981, -81.5992153],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753614',
#   'pos': [28.9612138, -81.5987432],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753615',
#   'pos': [28.9615142, -81.5981767],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753618',
#   'pos': [28.9617244, -81.5977132],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753619',
#   'pos': [28.9618071, -81.5974557],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753620',
#   'pos': [28.9619047, -81.597121],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753621',
#   'pos': [28.9619798, -81.5967605],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753622',
#   'pos': [28.9620549, -81.5963914],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753623',
#   'pos': [28.9621074, -81.5959966],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753624',
#   'pos': [28.962145, -81.595619],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '5'},
#   'id': '91753625',
#   'pos': [28.9621225, -81.5951469],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755765',
#   'pos': [28.9620999, -81.5947435],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755766',
#   'pos': [28.9620399, -81.59428],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755769',
#   'pos': [28.9614241, -81.5890872],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755770',
#   'pos': [28.9612513, -81.5878856],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755772',
#   'pos': [28.9611537, -81.5872934],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755773',
#   'pos': [28.9610636, -81.5868471],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755775',
#   'pos': [28.9609735, -81.5864522],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755776',
#   'pos': [28.9608233, -81.5859544],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755777',
#   'pos': [28.9606881, -81.5854824],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755779',
#   'pos': [28.9604778, -81.5848386],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755780',
#   'pos': [28.9603201, -81.5842378],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755781',
#   'pos': [28.960245, -81.5838602],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755782',
#   'pos': [28.9602225, -81.5834825],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755784',
#   'pos': [28.9602225, -81.5833108],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755786',
#   'pos': [28.9602, -81.5821264],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755787',
#   'pos': [28.9602075, -81.5812681],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755789',
#   'pos': [28.9602375, -81.5808818],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755790',
#   'pos': [28.9603201, -81.5805299],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755791',
#   'pos': [28.9604928, -81.5800149],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755792',
#   'pos': [28.9607181, -81.5794828],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755794',
#   'pos': [28.9610035, -81.5787446],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755795',
#   'pos': [28.9612288, -81.578161],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755796',
#   'pos': [28.9615517, -81.5773542],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755797',
#   'pos': [28.9625956, -81.5745561],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755798',
#   'pos': [28.9626782, -81.5743244],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755799',
#   'pos': [28.9627157, -81.5740583],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755801',
#   'pos': [28.9627383, -81.5738094],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755802',
#   'pos': [28.962911, -81.571758],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755803',
#   'pos': [28.962941, -81.5712602],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755804',
#   'pos': [28.9629786, -81.5707967],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755805',
#   'pos': [28.9630912, -81.5701187],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755807',
#   'pos': [28.9632114, -81.5696809],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755808',
#   'pos': [28.963309, -81.5693977],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755809',
#   'pos': [28.9633841, -81.569226],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755810',
#   'pos': [28.9635042, -81.5690544],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755811',
#   'pos': [28.9636694, -81.568814],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755812',
#   'pos': [28.9649085, -81.5674837],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755813',
#   'pos': [28.9650512, -81.5673292],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755814',
#   'pos': [28.9651488, -81.5671747],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755815',
#   'pos': [28.965314, -81.5669172],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755816',
#   'pos': [28.9655393, -81.5665481],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755818',
#   'pos': [28.9658622, -81.5659902],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755820',
#   'pos': [28.9662827, -81.5652692],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755821',
#   'pos': [28.9665155, -81.5648744],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755822',
#   'pos': [28.969324, -81.5610549],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '3'},
#   'id': '91755823',
#   'pos': [28.971021, -81.5588233],
#   'type': 'node'},
#  {'created': {'changeset': '13945590',
#    'timestamp': '2012-11-20T14:02:43Z',
#    'uid': '322785',
#    'user': 'BCNorwich',
#    'version': '3'},
#   'id': '91757649',
#   'pos': [28.9731699, -81.5559181],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757650',
#   'pos': [28.9738669, -81.554961],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757653',
#   'pos': [28.9740546, -81.5547206],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757654',
#   'pos': [28.9742424, -81.5544889],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757655',
#   'pos': [28.974385, -81.5542571],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757656',
#   'pos': [28.9744751, -81.554034],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757657',
#   'pos': [28.9745727, -81.5537765],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757658',
#   'pos': [28.9746779, -81.553519],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757660',
#   'pos': [28.9747379, -81.5531671],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757661',
#   'pos': [28.974753, -81.552798],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757662',
#   'pos': [28.9747605, -81.5523174],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757663',
#   'pos': [28.9747755, -81.5499828],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757664',
#   'pos': [28.974783, -81.5487812],
#   'type': 'node'},
#  {'created': {'changeset': '13729845',
#    'timestamp': '2012-11-03T02:16:00Z',
#    'uid': '135163',
#    'user': 'MikeN',
#    'version': '3'},
#   'id': '91757665',
#   'pos': [28.9748111, -81.5459723],
#   'type': 'node'},
#  {'created': {'changeset': '13729845',
#    'timestamp': '2012-11-03T02:16:00Z',
#    'uid': '135163',
#    'user': 'MikeN',
#    'version': '3'},
#   'id': '91757666',
#   'pos': [28.9748196, -81.5455923],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757668',
#   'pos': [28.9748356, -81.5452964],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757670',
#   'pos': [28.9748881, -81.5449617],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757671',
#   'pos': [28.9749632, -81.5446784],
#   'type': 'node'},
#  {'created': {'changeset': '13729845',
#    'timestamp': '2012-11-03T02:16:00Z',
#    'uid': '135163',
#    'user': 'MikeN',
#    'version': '4'},
#   'id': '91757672',
#   'pos': [28.9750139, -81.5445181],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757673',
#   'pos': [28.9751359, -81.5441892],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757675',
#   'pos': [28.9753311, -81.543803],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757676',
#   'pos': [28.9755038, -81.5435541],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757678',
#   'pos': [28.9757141, -81.543288],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757679',
#   'pos': [28.9759393, -81.5430305],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757680',
#   'pos': [28.9762697, -81.5427473],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757682',
#   'pos': [28.9767202, -81.5424726],
#   'type': 'node'},
#  {'created': {'changeset': '13681875',
#    'timestamp': '2012-10-30T03:26:45Z',
#    'uid': '38487',
#    'user': 'jumbanho',
#    'version': '3'},
#   'id': '91757683',
#   'pos': [28.9769658, -81.5423769],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757684',
#   'pos': [28.977351, -81.5422752],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757685',
#   'pos': [28.9777639, -81.5422323],
#   'type': 'node'},
#  {'created': {'changeset': '354197',
#    'timestamp': '2007-10-29T21:16:59Z',
#    'uid': '17666',
#    'user': 'tomfl',
#    'version': '2'},
#   'id': '91757686',
#   'pos': [28.9813529, -81.5422494],
#   'type': 'node'},
#  {'created': {'changeset': '14847589',
#    'timestamp': '2013-01-30T13:23:35Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '4'},
#   'id': '91785206',
#   'pos': [29.1741975, -81.6928011],
#   'type': 'node'},
#  {'created': {'changeset': '9773993',
#    'timestamp': '2011-11-08T15:12:23Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97374995',
#   'pos': [29.5927938, -81.2169987],
#   'type': 'node'},
#  {'created': {'changeset': '9773993',
#    'timestamp': '2011-11-08T15:12:23Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375003',
#   'pos': [29.5931383, -81.2159232],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:21Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375009',
#   'pos': [29.5217008, -81.2122543],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:22Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375012',
#   'pos': [29.5222012, -81.2110526],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:23Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375015',
#   'pos': [29.5224327, -81.2104518],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:24Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375016',
#   'pos': [29.5224252, -81.2102201],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:24Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375017',
#   'pos': [29.5223729, -81.2099883],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:25Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375019',
#   'pos': [29.5222758, -81.2098167],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:26Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375020',
#   'pos': [29.5202966, -81.2076881],
#   'type': 'node'},
#  {'created': {'changeset': '2785076',
#    'timestamp': '2009-10-08T18:16:26Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375021',
#   'pos': [29.5197514, -81.2071302],
#   'type': 'node'},
#  {'created': {'changeset': '20145320',
#    'timestamp': '2014-01-22T17:15:47Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375022',
#   'pos': [29.5179548, -81.206331],
#   'type': 'node'},
#  {'created': {'changeset': '15042688',
#    'timestamp': '2013-02-15T17:36:47Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '6'},
#   'id': '97375027',
#   'pos': [29.4712576, -81.252565],
#   'type': 'node'},
#  {'created': {'changeset': '3621119',
#    'timestamp': '2010-01-14T23:25:12Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375028',
#   'pos': [29.4718586, -81.2534292],
#   'type': 'node'},
#  {'created': {'changeset': '3667887',
#    'timestamp': '2010-01-20T16:02:57Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375029',
#   'pos': [29.472415, -81.2542656],
#   'type': 'node'},
#  {'created': {'changeset': '28588421',
#    'timestamp': '2015-02-03T12:42:09Z',
#    'uid': '369983',
#    'user': 'grouper',
#    'version': '3'},
#   'id': '97375032',
#   'pos': [29.6208447, -81.2006036],
#   'type': 'node'},
#  {'created': {'changeset': '28588421',
#    'timestamp': '2015-02-03T12:42:10Z',
#    'uid': '369983',
#    'user': 'grouper',
#    'version': '3'},
#   'id': '97375034',
#   'pos': [29.62202, -81.2011221],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375038',
#   'pos': [29.437806, -81.145825],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375039',
#   'pos': [29.437726, -81.145948],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375040',
#   'pos': [29.437445, -81.146235],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375041',
#   'pos': [29.436668, -81.149181],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375042',
#   'pos': [29.436532, -81.149301],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375045',
#   'pos': [29.435005, -81.153427],
#   'type': 'node'},
#  {'created': {'changeset': '19793377',
#    'timestamp': '2014-01-03T19:26:07Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375050',
#   'pos': [29.5624622, -81.2355274],
#   'type': 'node'},
#  {'created': {'changeset': '2563446',
#    'timestamp': '2009-09-21T23:50:50Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375052',
#   'pos': [29.5630557, -81.2352345],
#   'type': 'node'},
#  {'created': {'changeset': '2563446',
#    'timestamp': '2009-09-21T23:49:29Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375054',
#   'pos': [29.5636306, -81.2348912],
#   'type': 'node'},
#  {'created': {'changeset': '2563446',
#    'timestamp': '2009-09-21T23:49:29Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375055',
#   'pos': [29.5646086, -81.2343848],
#   'type': 'node'},
#  {'created': {'changeset': '19793740',
#    'timestamp': '2014-01-03T19:44:58Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375057',
#   'pos': [29.5649665, -81.2341846],
#   'type': 'node'},
#  {'created': {'changeset': '19793740',
#    'timestamp': '2014-01-03T19:44:59Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375059',
#   'pos': [29.5652302, -81.2340291],
#   'type': 'node'},
#  {'created': {'changeset': '19793740',
#    'timestamp': '2014-01-03T19:44:59Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '5'},
#   'id': '97375061',
#   'pos': [29.5655801, -81.2335543],
#   'type': 'node'},
#  {'created': {'changeset': '19793740',
#    'timestamp': '2014-01-03T19:44:59Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '6'},
#   'id': '97375062',
#   'pos': [29.5658461, -81.2330232],
#   'type': 'node'},
#  {'created': {'changeset': '19793740',
#    'timestamp': '2014-01-03T19:44:59Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '5'},
#   'id': '97375064',
#   'pos': [29.5662069, -81.2323736],
#   'type': 'node'},
#  {'created': {'changeset': '20105277',
#    'timestamp': '2014-01-20T15:12:47Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375068',
#   'pos': [29.578878, -81.2074079],
#   'type': 'node'},
#  {'created': {'changeset': '20105277',
#    'timestamp': '2014-01-20T15:12:47Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375070',
#   'pos': [29.5785147, -81.2085229],
#   'type': 'node'},
#  {'created': {'changeset': '20105277',
#    'timestamp': '2014-01-20T15:12:47Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'highway': 'turning_circle',
#   'id': '97375072',
#   'pos': [29.5783035, -81.2091286],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375079',
#   'pos': [29.618851, -81.463599],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375080',
#   'pos': [29.615209, -81.463598],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:00:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97375081',
#   'pos': [29.612274, -81.463598],
#   'type': 'node'},
#  {'created': {'changeset': '9901628',
#    'timestamp': '2011-11-21T20:41:01Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375083',
#   'pos': [29.4984466, -81.2614957],
#   'type': 'node'},
#  {'created': {'changeset': '9901628',
#    'timestamp': '2011-11-21T20:41:01Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375085',
#   'pos': [29.4984869, -81.2576969],
#   'type': 'node'},
#  {'created': {'changeset': '10126218',
#    'timestamp': '2011-12-15T19:10:28Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375089',
#   'pos': [29.4932621, -81.2298266],
#   'type': 'node'},
#  {'created': {'changeset': '10126218',
#    'timestamp': '2011-12-15T19:10:28Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375091',
#   'pos': [29.4927847, -81.2298006],
#   'type': 'node'},
#  {'created': {'changeset': '3667709',
#    'timestamp': '2010-01-20T15:38:46Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375095',
#   'pos': [29.461478, -81.2603094],
#   'type': 'node'},
#  {'created': {'changeset': '3667709',
#    'timestamp': '2010-01-20T15:38:46Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375098',
#   'pos': [29.4620464, -81.2597016],
#   'type': 'node'},
#  {'created': {'changeset': '3667709',
#    'timestamp': '2010-01-20T15:38:24Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375100',
#   'pos': [29.4625766, -81.2592315],
#   'type': 'node'},
#  {'created': {'changeset': '9775216',
#    'timestamp': '2011-11-08T17:44:47Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375103',
#   'pos': [29.4631272, -81.2587153],
#   'type': 'node'},
#  {'created': {'changeset': '3667709',
#    'timestamp': '2010-01-20T15:38:19Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375105',
#   'pos': [29.4636859, -81.2581885],
#   'type': 'node'},
#  {'created': {'changeset': '3667709',
#    'timestamp': '2010-01-20T15:38:22Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375106',
#   'pos': [29.464229, -81.2576755],
#   'type': 'node'},
#  {'created': {'changeset': '10763730',
#    'timestamp': '2012-02-22T21:46:11Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375114',
#   'pos': [29.5443049, -81.2364159],
#   'type': 'node'},
#  {'created': {'changeset': '4901885',
#    'timestamp': '2010-06-04T15:12:25Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375116',
#   'pos': [29.5445395, -81.236202],
#   'type': 'node'},
#  {'created': {'changeset': '4901885',
#    'timestamp': '2010-06-04T15:12:20Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375117',
#   'pos': [29.5446795, -81.236025],
#   'type': 'node'},
#  {'created': {'changeset': '4901885',
#    'timestamp': '2010-06-04T15:12:25Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375119',
#   'pos': [29.5449129, -81.2356924],
#   'type': 'node'},
#  {'created': {'changeset': '4901885',
#    'timestamp': '2010-06-04T15:12:25Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375120',
#   'pos': [29.5450575, -81.2355905],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:43Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375123',
#   'pos': [29.5459234, -81.2355596],
#   'type': 'node'},
#  {'created': {'changeset': '3017930',
#    'timestamp': '2009-11-02T17:39:48Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375124',
#   'pos': [29.5462557, -81.2353718],
#   'type': 'node'},
#  {'created': {'changeset': '3017930',
#    'timestamp': '2009-11-02T17:39:48Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375125',
#   'pos': [29.5465693, -81.2354919],
#   'type': 'node'},
#  {'created': {'changeset': '3017930',
#    'timestamp': '2009-11-02T17:39:50Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375128',
#   'pos': [29.5469426, -81.2359211],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:43Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375129',
#   'pos': [29.5474277, -81.2365],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:44Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375130',
#   'pos': [29.5474788, -81.2367428],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:43Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375131',
#   'pos': [29.5474688, -81.2368796],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:44Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375132',
#   'pos': [29.5473897, -81.237089],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:44Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97375136',
#   'pos': [29.5472643, -81.2372386],
#   'type': 'node'},
#  {'created': {'changeset': '10570321',
#    'timestamp': '2012-02-02T19:04:44Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'highway': 'turning_circle',
#   'id': '97375140',
#   'pos': [29.546631, -81.2375156],
#   'type': 'node'},
#  {'created': {'changeset': '5263017',
#    'timestamp': '2010-07-19T17:04:34Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375147',
#   'pos': [29.4681343, -81.2511959],
#   'type': 'node'},
#  {'created': {'changeset': '5263017',
#    'timestamp': '2010-07-19T17:04:34Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375149',
#   'pos': [29.4684052, -81.251081],
#   'type': 'node'},
#  {'created': {'changeset': '2907357',
#    'timestamp': '2009-10-20T22:09:16Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375151',
#   'pos': [29.4339718, -81.1067792],
#   'type': 'node'},
#  {'created': {'changeset': '2907357',
#    'timestamp': '2009-10-20T22:09:16Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375152',
#   'pos': [29.4339045, -81.1095601],
#   'type': 'node'},
#  {'created': {'changeset': '2907357',
#    'timestamp': '2009-10-20T22:09:16Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375154',
#   'pos': [29.4338223, -81.1097318],
#   'type': 'node'},
#  {'created': {'changeset': '2907357',
#    'timestamp': '2009-10-20T22:09:16Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '3'},
#   'id': '97375156',
#   'pos': [29.4334859, -81.1095258],
# ...
#    'version': '2'},
#   'id': '97377997',
#   'pos': [29.360564, -81.224469],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97377999',
#   'pos': [29.360862, -81.2246],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378001',
#   'pos': [29.361619, -81.225439],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378003',
#   'pos': [29.362787, -81.227088],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378005',
#   'pos': [29.363406, -81.227716],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378007',
#   'pos': [29.364117, -81.227978],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378009',
#   'pos': [29.365905, -81.228057],
#   'type': 'node'},
#  {'created': {'changeset': '9705539',
#    'timestamp': '2011-10-31T17:38:13Z',
#    'uid': '168862',
#    'user': 'SteveDorries',
#    'version': '4'},
#   'id': '97378011',
#   'pos': [29.5538681, -81.220107],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '97378020',
#   'pos': [29.552865, -81.2179111],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378023',
#   'pos': [29.330052, -81.203582],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378025',
#   'pos': [29.330396, -81.203518],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378027',
#   'pos': [29.331015, -81.20326],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378030',
#   'pos': [29.331088, -81.203294],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378032',
#   'pos': [29.33205, -81.203111],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378034',
#   'pos': [29.332646, -81.203137],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378035',
#   'pos': [29.332967, -81.20332],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378038',
#   'pos': [29.333563, -81.203242],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378040',
#   'pos': [29.334137, -81.202902],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378041',
#   'pos': [29.334475, -81.202563],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378042',
#   'pos': [29.33471, -81.202326],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378043',
#   'pos': [29.335352, -81.201018],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378045',
#   'pos': [29.335696, -81.200809],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378047',
#   'pos': [29.336498, -81.2006],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378049',
#   'pos': [29.338263, -81.2006],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378051',
#   'pos': [29.338583, -81.200705],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378053',
#   'pos': [29.338904, -81.200966],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378055',
#   'pos': [29.340578, -81.202536],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378056',
#   'pos': [29.341907, -81.202851],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378057',
#   'pos': [29.344177, -81.203557],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378059',
#   'pos': [29.344865, -81.203898],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378061',
#   'pos': [29.345621, -81.204866],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378062',
#   'pos': [29.346653, -81.20484],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378063',
#   'pos': [29.347799, -81.204683],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378065',
#   'pos': [29.348464, -81.204788],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378067',
#   'pos': [29.349518, -81.205338],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378068',
#   'pos': [29.350435, -81.206411],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378070',
#   'pos': [29.351605, -81.206332],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378071',
#   'pos': [29.352407, -81.205966],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378073',
#   'pos': [29.352682, -81.205678],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378074',
#   'pos': [29.353232, -81.204579],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378076',
#   'pos': [29.354058, -81.203533],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378078',
#   'pos': [29.355204, -81.202486],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378079',
#   'pos': [29.355365, -81.202434],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378080',
#   'pos': [29.355938, -81.201989],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378081',
#   'pos': [29.356282, -81.201492],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378083',
#   'pos': [29.357245, -81.198483],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378084',
#   'pos': [29.357795, -81.196494],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378087',
#   'pos': [29.358254, -81.195709],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378089',
#   'pos': [29.358369, -81.195212],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378091',
#   'pos': [29.35846, -81.194321],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378097',
#   'pos': [29.358438, -81.194112],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378104',
#   'pos': [29.3572, -81.193013],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378110',
#   'pos': [29.351468, -81.189689],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378115',
#   'pos': [29.351124, -81.189402],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378118',
#   'pos': [29.350964, -81.189375],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378122',
#   'pos': [29.350849, -81.189245],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378123',
#   'pos': [29.349634, -81.188564],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378126',
#   'pos': [29.349474, -81.188329],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378127',
#   'pos': [29.349061, -81.188224],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378129',
#   'pos': [29.347892, -81.187465],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378132',
#   'pos': [29.347658, -81.187332],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378134',
#   'pos': [29.346654, -81.186759],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378136',
#   'pos': [29.345875, -81.186706],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378138',
#   'pos': [29.345164, -81.186366],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378142',
#   'pos': [29.344499, -81.185555],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378146',
#   'pos': [29.343651, -81.185189],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378148',
#   'pos': [29.342504, -81.18498],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378150',
#   'pos': [29.341198, -81.184927],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378153',
#   'pos': [29.34106, -81.184849],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378160',
#   'pos': [29.340418, -81.184116],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378165',
#   'pos': [29.339432, -81.183698],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378171',
#   'pos': [29.338173, -81.183462],
#   'type': 'node'},
#  {'created': {'changeset': '2217625',
#    'timestamp': '2009-08-20T23:01:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '97378176',
#   'pos': [29.338104, -81.183384],
#   'type': 'node'},
#  ...]

# %% [markdown]
# ## 5. Data Overview

# %%
import os
print "The downloaded file is {} MB".format(os.path.getsize(filename)/1.0e6) # convert from bytes to megabytes
# Out:
# The downloaded file is 74.445532 MB

# %%
print "The json file is {} MB".format(os.path.getsize(filename + ".json")/1.0e6) # convert from bytes to megabytes
# Out:
# The json file is 80.163839 MB

# %%
import signal
import subprocess

# The os.setsid() is passed in the argument preexec_fn so
# it's run after the fork() and before  exec() to run the shell.
pro = subprocess.Popen("mongod", preexec_fn = os.setsid)

# %%
from pymongo import MongoClient

db_name = "osm"

client = MongoClient('localhost:27017')
db = client[db_name]

# %%
# Build mongoimport command
collection = filename[:filename.find(".")]
#working_directory = "/Users/jasondamiani/Developer/IPython/Notebooks/"
working_directory = "/Users/ducvu/Documents/ud032-master/final_project"

json_file = filename + ".json"

mongoimport_cmd = "mongoimport --db " + db_name + \
                  " --collection " + collection + \
                  " --file " + working_directory + json_file

# Before importing, drop collection if it exists
if collection in db.collection_names():
    print "dropping collection"
    db[collection].drop()

# Execute the command
print "Executing: " + mongoimport_cmd
subprocess.call(mongoimport_cmd.split())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-40-33cbb0539b98> in <module>()
#       9
#      10 # Before importing, drop collection if it exists
# ---> 11 if collection in db.collection_names():
#      12     print "dropping collection"
#      13     db[collection].drop()
#
# /Users/ducvu/anaconda/lib/python2.7/site-packages/pymongo-3.1.0.dev0-py2.7-macosx-10.5-x86_64.egg/pymongo/database.pyc in collection_names(self, include_system_collections)
#     488         """
#     489         with self.__client._socket_for_reads(
# --> 490             ReadPreference.PRIMARY) as (sock_info, slave_okay):
#     491
#     492             results = self._list_collections(sock_info, slave_okay)
#
# /Users/ducvu/anaconda/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /Users/ducvu/anaconda/lib/python2.7/site-packages/pymongo-3.1.0.dev0-py2.7-macosx-10.5-x86_64.egg/pymongo/mongo_client.pyc in _socket_for_reads(self, read_preference)
#     719         topology = self._get_topology()
#     720         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# --> 721         with self._get_socket(read_preference) as sock_info:
#     722             slave_ok = (single and not sock_info.is_mongos) or (
#     723                 preference != ReadPreference.PRIMARY)
#
# /Users/ducvu/anaconda/lib/python2.7/contextlib.pyc in __enter__(self)
#      15     def __enter__(self):
#      16         try:
# ---> 17             return self.gen.next()
#      18         except StopIteration:
#      19             raise RuntimeError("generator didn't yield")
#
# /Users/ducvu/anaconda/lib/python2.7/site-packages/pymongo-3.1.0.dev0-py2.7-macosx-10.5-x86_64.egg/pymongo/mongo_client.pyc in _get_socket(self, selector)
#     683     @contextlib.contextmanager
#     684     def _get_socket(self, selector):
# --> 685         server = self._get_topology().select_server(selector)
#     686         try:
#     687             with server.get_socket(self.__all_credentials) as sock_info:
#
# /Users/ducvu/anaconda/lib/python2.7/site-packages/pymongo-3.1.0.dev0-py2.7-macosx-10.5-x86_64.egg/pymongo/topology.pyc in select_server(self, selector, server_selection_timeout, address)
#     139         return random.choice(self.select_servers(selector,
#     140                                                  server_selection_timeout,
# --> 141                                                  address))
#     142
#     143     def select_server_by_address(self, address,
#
# /Users/ducvu/anaconda/lib/python2.7/site-packages/pymongo-3.1.0.dev0-py2.7-macosx-10.5-x86_64.egg/pymongo/topology.pyc in select_servers(self, selector, server_selection_timeout, address)
#     115                 if server_timeout == 0 or now > end_time:
#     116                     raise ServerSelectionTimeoutError(
# --> 117                         self._error_message(selector))
#     118
#     119                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %% [markdown]
# ## 6. Additional Ideas

# %% [markdown]
# ### Additional data exploration using MongoDB queries

# %% [markdown]
# ### Conclusion
